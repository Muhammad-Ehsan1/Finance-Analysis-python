# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
sns.set_style("darkgrid")

# %%
## import Dataset
df = pd.read_csv("E:\data analytics\datasets\Finance_data.csv")
df.head()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Muhammad Ehsan\AppData\Local\Temp\ipykernel_6932\2542138821.py:2: SyntaxWarning: invalid escape sequence '\d'
#   df = pd.read_csv("E:\data analytics\datasets\Finance_data.csv")
#    gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0  Female   34                Yes             1              2           5
# 1  Female   23                Yes             4              3           2
# 2    Male   30                Yes             3              6           4
# 3    Male   22                Yes             2              1           3
# 4  Female   24                 No             2              1           3
#
#    Government_Bonds  Fixed_Deposits  PPF  Gold  ...           Duration  \
# 0                 3               7    6     4  ...          1-3 years
# 1                 1               5    6     7  ...  More than 5 years
# ...

# %%
## Drop Unused columns
df.drop(["Mutual_Funds","Equity_Market","Debentures","Government_Bonds","PPF","Fixed_Deposits","Gold"],axis = 1 , inplace = True)

# %%
## Replace Black values with Nan
df.replace(r'^ s*$' ,np.nan , regex=True)
# Out:
#     gender  age Investment_Avenues Stock_Marktet          Factor  \
# 0   Female   34                Yes           Yes         Returns
# 1   Female   23                Yes            No  Locking Period
# 2     Male   30                Yes           Yes         Returns
# 3     Male   22                Yes           Yes         Returns
# 4   Female   24                 No            No         Returns
# 5   Female   24                 No            No            Risk
# 6   Female   27                Yes           Yes         Returns
# 7     Male   21                Yes           Yes            Risk
# 8     Male   35                Yes           Yes         Returns
# 9     Male   31                Yes           Yes         Returns
# 10  Female   35                Yes           Yes            Risk
# 11    Male   29                Yes           Yes            Risk
# 12  Female   21                 No            No         Returns
# ...

# %%
## ploting
sns.countplot(x = "gender", data= df, linewidth = 3, palette= "Set2", edgecolor = "black")
plt.show()
# Out:
# C:\Users\Muhammad Ehsan\AppData\Local\Temp\ipykernel_6932\699614787.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = "gender", data= df, linewidth = 3, palette= "Set2", edgecolor = "black")

# %%
sns.countplot(x = "age", data= df, linewidth = 2, palette= "Set3", edgecolor = "black")
plt.show()
# Out:
# C:\Users\Muhammad Ehsan\AppData\Local\Temp\ipykernel_6932\4235265613.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = "age", data= df, linewidth = 2, palette= "Set3", edgecolor = "black")

# %%
plt.figure(figsize=(18,6))
plt.subplot(1,2,1)
sns.countplot(x = df["gender"],hue=df["Investment_Avenues"], palette="summer", linewidth = 3, edgecolor = "white")
plt.title("Investment Avenues")

plt.subplot(1,2,2)
sns.countplot(x = df["gender"],hue=df["Stock_Marktet"], palette="hot", linewidth = 3, edgecolor = "white")
plt.title("Stock Market")
# Out:
# Text(0.5, 1.0, 'Stock Market')

# %%
sns.countplot(x = df["Factor"], palette="coolwarm", linewidth = 2, edgecolor = "black")
plt.show()
# Out:
# C:\Users\Muhammad Ehsan\AppData\Local\Temp\ipykernel_6932\4087837484.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = df["Factor"], palette="coolwarm", linewidth = 2, edgecolor = "black")

# %%
plt.figure(figsize=(18,6))
sns.pointplot(x = "Purpose",y = "age",data = df ,linestyles = "--", capsize= .3 ,color="Blue" )
plt.show()

# %%
plt.figure(figsize=(18,6))
plt.subplot(1,2,1)
sns.countplot(x = df["Duration"],hue=df["gender"], palette="viridis", linewidth = 2, edgecolor = "black")
plt.title("DURATION")

plt.subplot(1,2,2)
sns.countplot(x = df["Invest_Monitor"],hue=df["gender"], palette="seismic", linewidth = 2, edgecolor = "black")
plt.title("INVESTMENT MONITORING")
plt.show()
